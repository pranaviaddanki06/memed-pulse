# %% [markdown]
# # MEMED PULSE model experiment
# Synthetic-data exploration, baseline comparison, and feature review. Run `ml/data/generate_dataset.py` then `ml/training/train.py` for the executable workflow.

# %%
import pandas as pd
from pathlib import Path
df = pd.read_csv(Path('../ml/data/prototype_content.csv'))
df.describe()
